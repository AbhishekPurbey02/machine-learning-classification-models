# %%
# Imported the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Imported the dataset in the code and divides into feature and dependent variable
Dataset = pd.read_csv('Social_Network_Ads.csv')
x = Dataset.iloc[:, :-1]
y = Dataset.iloc[:, -1]
print(x)
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64
